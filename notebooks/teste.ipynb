# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

fig= plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

plt.plot(np.random.randn(20), 'k--')
